# %% [markdown]
# # CAPSTONE PROJECT
#
# Notebook này làm sạch dữ liệu booking khách sạn Bồ Đào Nha từ workbook nguồn. Kết quả được ghi vào `data/data_valid.csv` và `data/data_invalid.csv` để notebook phân tích và Dash app dùng chung một nguồn dữ liệu.

# %%
# Import thư viện chuẩn để xử lý path, ngày tháng và dữ liệu dạng bảng.
import calendar
from datetime import datetime
from pathlib import Path

import pandas as pd
from pandas import Timestamp

BASE_DIR = Path.cwd()
DATA_DIR = BASE_DIR / 'data'
EXCEL_DIR = BASE_DIR / 'excel'

RAW_BOOKING_PATH = EXCEL_DIR / 'portugal_hotel_booking.xlsx'
COUNTRY_CODES_PATH = DATA_DIR / 'country_codes_list.csv'
VALID_OUTPUT_PATH = DATA_DIR / 'data_valid.csv'
INVALID_OUTPUT_PATH = DATA_DIR / 'data_invalid.csv'

# Đảm bảo thư mục output tồn tại khi notebook chạy lại từ môi trường mới.
DATA_DIR.mkdir(exist_ok=True)

# %%
# Khai báo tên cột gốc để tránh gõ lặp literal string ở các bước làm sạch.
CN_HTL = 'hotel'
CN_LT = 'lead_time'
CN_D2 = 'arrival_date_day_of_month'
CN_M2 = 'arrival_date_month'
CN_Y4 = 'arrival_date_year'
CN_ADT = 'adults'
CN_CH = 'children'
CN_CNTY = 'country'
CN_MS = 'market_segment'
CN_AG = 'agent'
CN_CT = 'customer_type'
CN_ADR = 'average_daily_rate'

# %%
# Chuyển Series sang numeric; giá trị không parse được sẽ thành NaN để lọc ở mask hợp lệ.
def try_prs_num(series):
    return pd.to_numeric(series, errors='coerce')


# Chuyển Series sang integer nullable để vẫn giữ được NaN trong lúc kiểm tra dữ liệu lỗi.
def try_prs_int(series):
    return pd.to_numeric(series, errors='coerce').astype('Int64')

# %%
# Đọc workbook nguồn và bảng mã quốc gia sau khi đã gom file vào `excel/` và `data/`.
df = pd.read_excel(RAW_BOOKING_PATH)
country_codes_df = pd.read_csv(COUNTRY_CODES_PATH)
valid_country_codes = set(country_codes_df['Country'].dropna().astype(str).str.strip().unique())

# %%
# Chuẩn hóa từng cột thành Series đúng kiểu để mask hợp lệ nhất quán.
hotel = df[CN_HTL].astype('string').str.strip()
lead_time = try_prs_int(df[CN_LT])
day = try_prs_int(df[CN_D2])
month = df[CN_M2].astype('string').str.strip()
year = try_prs_int(df[CN_Y4])
adults = try_prs_int(df[CN_ADT])
children = try_prs_int(df[CN_CH])
country = df[CN_CNTY].astype('string').str.strip().str.upper()
mkt_seg = df[CN_MS].astype('string').str.strip()
agent = try_prs_int(df[CN_AG])
cust_type = df[CN_CT].astype('string').str.strip()
avg_dly_rate = try_prs_num(df[CN_ADR]).round(2)

# %%
# Mask hợp lệ cơ bản: đủ kiểu dữ liệu, không âm, có ít nhất một khách, và mã quốc gia tồn tại.
valid_months = set(calendar.month_name[1:])
guest_count = adults.fillna(0) + children.fillna(0)

base_valids = (lead_time.notna()
               & day.notna()
               & year.notna()
               & adults.notna()
               & children.notna()
               & agent.notna()
               & avg_dly_rate.notna()
               & lead_time.ge(0)
               & day.gt(0)
               & month.isin(valid_months)
               & year.gt(0)
               & adults.ge(0)
               & children.ge(0)
               & guest_count.gt(0)
               & agent.ge(0)
               & avg_dly_rate.ge(0)
               & country.isin(valid_country_codes))

# %%
# Ghép ngày từ year/month/day; ngày lỗi hoặc ngày tương lai sẽ bị loại.
month_map = {month_name: month_number for month_number, month_name in enumerate(calendar.month_name) if month_number != 0}
month_num = month.map(month_map)

date_parts = pd.DataFrame({
    'year': year,
    'month': month_num,
    'day': day
})
arrival_date = pd.to_datetime(date_parts, errors='coerce')
date_valids = arrival_date.notna() & arrival_date.lt(Timestamp.today())

# %%
# Lọc outlier bằng biến thể Tukey fence dùng Q3=0.99 để cắt đuôi phải rất dài của ADR/children.
def outside_iqr_bounds(series, upper_quantile=0.99):
    clean_series = series.dropna()
    if clean_series.empty:
        return pd.Series(False, index=series.index)

    q1 = clean_series.quantile(0.25)
    q3 = clean_series.quantile(upper_quantile)
    iqr = q3 - q1
    lower_fence = q1 - 1.5 * iqr
    upper_fence = q3 + 1.5 * iqr
    return (series < lower_fence) | (series > upper_fence)

# %%
# Chỉ tính outlier trên các dòng đã qua kiểm tra cơ bản để không bị dữ liệu lỗi làm lệch ngưỡng.
candidate_mask = base_valids & date_valids
adr_outliers = outside_iqr_bounds(avg_dly_rate.loc[candidate_mask]).reindex(df.index, fill_value=False)
children_outliers = outside_iqr_bounds(children.loc[candidate_mask]).reindex(df.index, fill_value=False)

valids = candidate_mask & ~adr_outliers & ~children_outliers
invalids = ~valids

# %%
# Assemble dữ liệu sạch với tên cột thân thiện cho notebook phân tích và Dash app.
valid_df = pd.DataFrame({
    'Hotel': hotel.loc[valids],
    'Lead Time': lead_time.loc[valids],
    'Arrival Date Day': day.loc[valids],
    'Arrival Date Month': month.loc[valids],
    'Arrival Date Year': year.loc[valids],
    'Arrival Date': arrival_date.loc[valids],
    'Weekday': arrival_date.loc[valids].apply(lambda x: datetime.strftime(x, '%A')),
    'Adults': adults.loc[valids],
    'Children': children.loc[valids],
    'Country': country.loc[valids],
    'Market Segment': mkt_seg.loc[valids],
    'Agent': agent.loc[valids],
    'Customer Type': cust_type.loc[valids],
    'Average Daily Rate': avg_dly_rate.loc[valids]
})

invalid_df = df.loc[invalids].drop(columns=['Unnamed: 0'], errors='ignore').copy()

# %%
# Ghi output không kèm index để tránh sinh cột `Unnamed: 0` ở các bước phân tích sau.
valid_df.to_csv(VALID_OUTPUT_PATH, index=False)
invalid_df.to_csv(INVALID_OUTPUT_PATH, index=False)

def repo_relative_path(path):
    return path.relative_to(BASE_DIR).as_posix()


print(f'Dữ liệu hợp lệ: {len(valid_df):,} dòng -> {repo_relative_path(VALID_OUTPUT_PATH)}')
print(f'Dữ liệu bị loại: {len(invalid_df):,} dòng -> {repo_relative_path(INVALID_OUTPUT_PATH)}')
# Out:
# Dữ liệu hợp lệ: 78,658 dòng -> data/data_valid.csv
# Dữ liệu bị loại: 1,064 dòng -> data/data_invalid.csv

# %% [markdown]
# ## Tóm tắt làm sạch
#
# - Dữ liệu nguồn được đọc từ `excel/portugal_hotel_booking.xlsx`; mã quốc gia được đọc từ `data/country_codes_list.csv`.
# - Các dòng hợp lệ phải parse được ngày/số, không âm, có ít nhất một khách, ngày booking không ở tương lai và mã quốc gia có trong bảng tham chiếu.
# - Average Daily Rate và Children được lọc outlier bằng ngưỡng IQR mở rộng trước khi ghi `data/data_valid.csv`; phần còn lại được ghi vào `data/data_invalid.csv`.
